# %%
print(info.to_string)
# Out:
# <bound method DataFrame.to_string of       Price  Units  vacancies
# 0     $750       3          1
# 1     1,200      5          0
# 2     $950       2          0
# 3     1,500      6          0
# 4     $850       4          1
# 5     1,300      5          2
# 6     1,100      3          1
# 7     1,600      7          0
# 8     $900       3          1
# 9     1,250      4          0
# 10    1,050      3          0
# 11    1,400      5          2
# 12    $800       2          0
# 13    1,350      4          1
# 14    1,050      7          4
# 15    1,700      2          0
# 16    $950       6          3
# 17    1,550      4          1
# 18    $850       5          0
# 19    1,300      3          1
# 20    1,100      8          0
# 21    1,750      3          0
# 22    1,000      6          0
# 23    1,450      3          1
# 24    $900       5          2
# 25    1,400      4          1
# 26    1,150      8          5
# 27    1,800      2          0
# 28    $950       6          3
# ...

# %%
print(average_rent)
# Out:
# 1338.0

# %%
print(vacancies)
# Out:
#     Price  Units  vacancies
# 0     750      3          1
# 4     850      4          1
# 5    1300      5          2
# 6    1100      3          1
# 8     900      3          1
# 11   1400      5          2
# 13   1350      4          1
# 14   1050      7          4
# 16    950      6          3
# 17   1550      4          1
# 19   1300      3          1
# 23   1450      3          1
# 24    900      5          2
# 25   1400      4          1
# 26   1150      8          5
# 28    950      6          3
# 29   1500      5          2
# 32   1050      7          4
# 33   1600      4          2
# 34   1250      8          6
# 35   1900      3          1
# 36   1100      7          4
# 41   1700      4          1
# 43   2000      5          2
# 44   1200      8          6
# 47   2050      4          1
# 48   1250      8          5

# %%
#The only significant piece of info we get from this is that there is a tight correlation between units and vacancies. This makes sense on multiple levels: there are going to be more vacancies as there are more options available as number of units increases, but also in reality there is less risk for a unit/property ratio of 1 so many times small businesses or local land owners typically have 1 unit to mitigate risk.

# %%
print(average_rent)
# Out:
# 1338.0

# %%
data
# Out:
#       Price  Units  vacancies
# 0     $750       3          1
# 1     1,200      5          0
# 2     $950       2          0
# 3     1,500      6          0
# 4     $850       4          1
# 5     1,300      5          2
# 6     1,100      3          1
# 7     1,600      7          0
# 8     $900       3          1
# 9     1,250      4          0
# 10    1,050      3          0
# 11    1,400      5          2
# 12    $800       2          0
# 13    1,350      4          1
# 14    1,050      7          4
# 15    1,700      2          0
# 16    $950       6          3
# 17    1,550      4          1
# 18    $850       5          0
# 19    1,300      3          1
# 20    1,100      8          0
# 21    1,750      3          0
# 22    1,000      6          0
# 23    1,450      3          1
# 24    $900       5          2
# 25    1,400      4          1
# 26    1,150      8          5
# 27    1,800      2          0
# 28    $950       6          3
# 29    1,500      5          2
# ...

# %%
vacancies
# Out:
#     Price  Units  vacancies
# 0   $750       3          1
# 4   $850       4          1
# 5   1,300      5          2
# 6   1,100      3          1
# 8   $900       3          1
# 11  1,400      5          2
# 13  1,350      4          1
# 14  1,050      7          4
# 16  $950       6          3
# 17  1,550      4          1
# 19  1,300      3          1
# 23  1,450      3          1
# 24  $900       5          2
# 25  1,400      4          1
# 26  1,150      8          5
# 28  $950       6          3
# 29  1,500      5          2
# 32  1,050      7          4
# 33  1,600      4          2
# 34  1,250      8          6
# 35  1,900      3          1
# 36  1,100      7          4
# 41  1,700      4          1
# 43  2,000      5          2
# 44  1,200      8          6
# 47  2,050      4          1
# 48  1,250      8          5

# %%
data
# Out:
#       Price  Units  vacancies
# 0     $750       3          1
# 1     1,200      5          0
# 2     $950       2          0
# 3     1,500      6          0
# 4     $850       4          1
# 5     1,300      5          2
# 6     1,100      3          1
# 7     1,600      7          0
# 8     $900       3          1
# 9     1,250      4          0
# 10    1,050      3          0
# 11    1,400      5          2
# 12    $800       2          0
# 13    1,350      4          1
# 14    1,050      7          4
# 15    1,700      2          0
# 16    $950       6          3
# 17    1,550      4          1
# 18    $850       5          0
# 19    1,300      3          1
# 20    1,100      8          0
# 21    1,750      3          0
# 22    1,000      6          0
# 23    1,450      3          1
# 24    $900       5          2
# 25    1,400      4          1
# 26    1,150      8          5
# 27    1,800      2          0
# 28    $950       6          3
# 29    1,500      5          2
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv('Rent_Info.csv')
prices = data['Price']
prices = prices.str.replace('$', '').str.replace(',', '').str.strip()
prices = pd.to_numeric(prices)
data['Price'] = prices

vacancies = pd.read_csv('Rent_Info.csv')
pr = vacancies['Price']
pr = pr.str.replace('$', '').str.replace(',', '').str.strip()
pr = pd.to_numeric(pr)
vacancies['Price'] = pr
for x in vacancies.index:
    if vacancies.loc[x, 'vacancies'] == 0:
        vacancies.drop(x, inplace = True)

graph = data.plot()

average_rent = prices.mean()

# %%
#Simple plot of the data

# %%
data.corr()
# Out:
#               Price     Units  vacancies
# Price      1.000000 -0.168090  -0.232165
# Units     -0.168090  1.000000   0.412369
# vacancies -0.232165  0.412369   1.000000

# %%
vacancies.corr()
# Out:
#               Price     Units  vacancies
# Price      1.000000 -0.235533  -0.262564
# Units     -0.235533  1.000000   0.962391
# vacancies -0.262564  0.962391   1.000000

# %%
data['vacancies'].plot(kind = 'hist')
data['Units'].plot(kind = 'hist', color = 'red')
# Out:
# <Axes: ylabel='Frequency'>

# %%
#shows the amount of vacancies (blue) and units (red) per property.

# %%
price_2[0]
# Out:
# 750

# %%
price_2.dtype
# Out:
# dtype('int64')

# %%
vacancies_2
# Out:
# 0     1
# 1     0
# 2     0
# 3     0
# 4     1
# 5     2
# 6     1
# 7     0
# 8     1
# 9     0
# 10    0
# 11    2
# 12    0
# 13    1
# 14    4
# 15    0
# 16    3
# 17    1
# 18    0
# 19    1
# 20    0
# 21    0
# 22    0
# 23    1
# 24    2
# 25    1
# 26    5
# 27    0
# 28    3
# 29    2
# 30    0
# 31    0
# 32    4
# 33    2
# 34    6
# 35    1
# 36    4
# 37    0
# 38    0
# 39    0
# 40    0
# 41    1
# 42    0
# 43    2
# 44    6
# 45    0
# 46    0
# 47    1
# 48    5
# 49    0
# Name: vacancies, dtype: int64

# %%
lost_revenue
# Out:
# 0      750
# 1        0
# 2        0
# 3        0
# 4      850
# 5     2600
# 6     1100
# 7        0
# 8      900
# 9        0
# 10       0
# 11    2800
# 12       0
# 13    1350
# 14    4200
# 15       0
# 16    2850
# 17    1550
# 18       0
# 19    1300
# 20       0
# 21       0
# 22       0
# 23    1450
# 24    1800
# 25    1400
# 26    5750
# 27       0
# 28    2850
# 29    3000
# 30       0
# 31       0
# 32    4200
# 33    3200
# 34    7500
# 35    1900
# 36    4400
# 37       0
# 38       0
# 39       0
# 40       0
# 41    1700
# 42       0
# 43    4000
# 44    7200
# 45       0
# 46       0
# 47    2050
# 48    6250
# 49       0
# dtype: int64

# %%
lost_revenue.max()
# Out:
# 7500

# %%
lost_revenue.sort_values(ascending = False)
# Out:
# 34    7500
# 44    7200
# 48    6250
# 26    5750
# 36    4400
# 32    4200
# 14    4200
# 43    4000
# 33    3200
# 29    3000
# 16    2850
# 28    2850
# 11    2800
# 5     2600
# 47    2050
# 35    1900
# 24    1800
# 41    1700
# 17    1550
# 23    1450
# 25    1400
# 13    1350
# 19    1300
# 6     1100
# 8      900
# 4      850
# 0      750
# 27       0
# 39       0
# 2        0
# 3        0
# 46       0
# 45       0
# 7        0
# 9        0
# 42       0
# 10       0
# 40       0
# 38       0
# 1        0
# 37       0
# 12       0
# 15       0
# 18       0
# 20       0
# 21       0
# 31       0
# 30       0
# 22       0
# 49       0
# dtype: int64

# %%
new_data.corr()
# Out:
#               Price     Units  vacancies
# Price      1.000000 -0.168090  -0.232165
# Units     -0.168090  1.000000   0.412369
# vacancies -0.232165  0.412369   1.000000

# %%
new_data.corr()
# Out:
#                  Price     Units  vacancies  lost_revenue
# Price         1.000000 -0.168090  -0.232165     -0.101629
# Units        -0.168090  1.000000   0.412369      0.379118
# vacancies    -0.232165  0.412369   1.000000      0.979435
# lost_revenue -0.101629  0.379118   0.979435      1.000000

# %%
#I proved that the vacancies cause large lost revenue with .979 correlation

# %%
new_data
# Out:
#     Price  Units  vacancies  lost_revenue
# 0     750      3          1           750
# 1    1200      5          0             0
# 2     950      2          0             0
# 3    1500      6          0             0
# 4     850      4          1           850
# 5    1300      5          2          2600
# 6    1100      3          1          1100
# 7    1600      7          0             0
# 8     900      3          1           900
# 9    1250      4          0             0
# 10   1050      3          0             0
# 11   1400      5          2          2800
# 12    800      2          0             0
# 13   1350      4          1          1350
# 14   1050      7          4          4200
# 15   1700      2          0             0
# 16    950      6          3          2850
# 17   1550      4          1          1550
# 18    850      5          0             0
# 19   1300      3          1          1300
# 20   1100      8          0             0
# ...
